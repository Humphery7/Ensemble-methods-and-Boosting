# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("documents/datasets for data science/Data_for_UCI_named.csv")

# %%
data.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
data.tail()
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4      stab     stabf
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  0.023892  unstable
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120 -0.025803    stable
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984 -0.031810    stable
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  0.037789  unstable
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  0.045263  unstable

# %%
data.isna().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
data.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
data.drop(columns='stab',inplace=True)

# %%
data.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  unstable

# %%
data3 = data.corr()

# %%
data3
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# tau1  1.000000  0.015586 -0.005970 -0.017265  0.027183 -0.015485 -0.015924
# tau2  0.015586  1.000000  0.014273 -0.001965 -0.004769  0.006573  0.007673
# tau3 -0.005970  0.014273  1.000000  0.004354  0.016953 -0.003134 -0.008780
# tau4 -0.017265 -0.001965  0.004354  1.000000 -0.003173  0.010553  0.006169
# p1    0.027183 -0.004769  0.016953 -0.003173  1.000000 -0.573157 -0.584554
# p2   -0.015485  0.006573 -0.003134  0.010553 -0.573157  1.000000  0.002388
# p3   -0.015924  0.007673 -0.008780  0.006169 -0.584554  0.002388  1.000000
# p4   -0.015807 -0.005963 -0.017531 -0.011211 -0.579239 -0.006844  0.012953
# g1    0.010521 -0.001742 -0.011605 -0.004149  0.000721  0.015603 -0.003219
# g2    0.015350  0.015383  0.007671  0.008431  0.015405 -0.018032 -0.011575
# g3   -0.001279  0.016508  0.014702  0.003260  0.001069  0.007555 -0.005897
# ...

# %%
data.plot(kind='scatter', x='p1',y='p2')
# Out:
# <AxesSubplot:xlabel='p1', ylabel='p2'>

# %%
# %matplotlib inline
fig = plt.figure(figsize=(30,18))
sns.heatmap(data.corr(),linewidth=0.9,annot=True,cmap='RdYlGn',xticklabels=2,yticklabels=2)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

data_ = data.drop(columns='stabf')
x_train, x_test, y_train, y_test = train_test_split(data_,data['stabf'],test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
y_train = label.fit_transform(y_train)

# %%
y_train = pd.Series(y_train)

# %%
y_train
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 7995    0
# 7996    0
# 7997    1
# 7998    0
# 7999    1
# Length: 8000, dtype: int32

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

n_estimators = [50, 100, 300, 500, 1000]
min_samples_split = [2, 3, 5, 7, 9]
min_samples_leaf = [1, 2, 4, 6, 8]
max_features = ['auto', 'sqrt', 'log2', None]
hyperparameter_grid = {'n_estimators': n_estimators,'min_samples_leaf': min_samples_leaf, 'min_samples_split': min_samples_split,'max_features': max_features}

light = LGBMClassifier(random_state=1)
xgbc = XGBClassifier(random_state=1,use_label_encoder=False)
random = RandomForestClassifier(random_state=1)
extra  = ExtraTreesClassifier(n_estimators=1000,mrandom_state=1)
cv = RandomizedSearchCV(estimator=extra,param_distributions=hyperparameter_grid,cv=5,random_state=1 )

model1 = random.fit(x_train,y_train)
model2 = cv.fit(x_train,y_train)
model3 = xgbc.fit(x_train,y_train)
model4 = light.fit(x_train,y_train)


#predict1 = model1.predict(x_test)
#predict2 = model2.predict(x_test)
#predict3 = model3.predict(x_test)
#predict4 = model4.predict(x_test)
# Out:
# [19:27:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
predict1 = model1.predict(x_test)
predict2 = model2.predict(x_test)
predict3 = model3.predict(x_test)
predict4 = model4.predict(x_test)

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
y_test = label.fit_transform(y_test)
y_train = pd.Series(y_train)

# %%
accuracy1 = accuracy_score(predict1,y_test)
accuracy2 = accuracy_score(predict2,y_test)
accuracy3 = accuracy_score(predict3,y_test)
accuracy4 = accuracy_score(predict4,y_test)

# %%
print(round(accuracy1,4))
print(round(accuracy2,4))
print(round(accuracy3,4))
print(round(accuracy4,4))
# Out:
# 0.9065
# 0.918
# 0.939
# 0.937

# %%
print(cv.best_params_)
# Out:
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': None}

# %%
extra  = ExtraTreesClassifier(n_estimators=1000,min_samples_split=2,min_samples_leaf=8,max_features=None,random_state=1)

model = extra.fit(x_train,y_train)

# %%
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# tau1  1.000000  0.015630 -0.008555 -0.022868  0.035054 -0.013109 -0.027889
# tau2  0.015630  1.000000  0.007527 -0.001468 -0.007813  0.008964  0.008385
# tau3 -0.008555  0.007527  1.000000  0.001893  0.021722  0.004125 -0.015922
# tau4 -0.022868 -0.001468  0.001893  1.000000 -0.016061  0.020383  0.009671
# p1    0.035054 -0.007813  0.021722 -0.016061  1.000000 -0.573834 -0.586385
# p2   -0.013109  0.008964  0.004125  0.020383 -0.573834  1.000000  0.005219
# p3   -0.027889  0.008385 -0.015922  0.009671 -0.586385  0.005219  1.000000
# p4   -0.019984 -0.003761 -0.026003 -0.002128 -0.579137 -0.007909  0.015373
# g1    0.016586 -0.004837 -0.002438 -0.006386 -0.002437  0.012058  0.005394
# g2    0.008606  0.010956  0.019264  0.007497  0.014265 -0.018573 -0.013668
# g3   -0.001565  0.011618  0.013009  0.014820  0.010769 -0.003117 -0.012574
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
data['stabf'] = label.fit_transform(data['stabf'])

# %%
data['stabf']
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    0
# 9997    0
# 9998    1
# 9999    1
# Name: stabf, Length: 10000, dtype: int32

# %%
data.corr()
# Out:
#            tau1      tau2      tau3      tau4        p1        p2        p3  \
# tau1   1.000000  0.015586 -0.005970 -0.017265  0.027183 -0.015485 -0.015924
# tau2   0.015586  1.000000  0.014273 -0.001965 -0.004769  0.006573  0.007673
# tau3  -0.005970  0.014273  1.000000  0.004354  0.016953 -0.003134 -0.008780
# tau4  -0.017265 -0.001965  0.004354  1.000000 -0.003173  0.010553  0.006169
# p1     0.027183 -0.004769  0.016953 -0.003173  1.000000 -0.573157 -0.584554
# p2    -0.015485  0.006573 -0.003134  0.010553 -0.573157  1.000000  0.002388
# p3    -0.015924  0.007673 -0.008780  0.006169 -0.584554  0.002388  1.000000
# p4    -0.015807 -0.005963 -0.017531 -0.011211 -0.579239 -0.006844  0.012953
# g1     0.010521 -0.001742 -0.011605 -0.004149  0.000721  0.015603 -0.003219
# g2     0.015350  0.015383  0.007671  0.008431  0.015405 -0.018032 -0.011575
# g3    -0.001279  0.016508  0.014702  0.003260  0.001069  0.007555 -0.005897
# ...
